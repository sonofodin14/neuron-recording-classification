# %%
# Third-Party Imports
import matplotlib.pyplot as plt
import scipy.io as spio
import scipy.signal as spsig

# %%
# Load in matlab data and create arrays
mat = spio.loadmat('D1.mat', squeeze_me=True)
d = mat['d']
Index = mat['Index']
Class = mat['Class']

# %%
# Explore first neuron spike
d_short = d[1400:1500]
plt.plot(d_short)
# plt.show()

# %%
# Spike Detection
peaks = spsig.find_peaks(d, height=1)
print(peaks)
# plt.plot(d)
# plt.scatter(peaks, d)
# Out:
# (array([   1437,    1441,    1450, ..., 1439858, 1439860, 1439862],
#       dtype=int64), {'peak_heights': array([4.93276674, 5.2415127 , 3.06979014, ..., 2.11693521, 1.82755024,
#        1.19752834])})
